# %% [markdown]
# # Performance of Sorting Algorithms

# %% [markdown]
# ## sortperf.py on mother

# %%
# %run sortperf.py
# Out:
# Number of iterations: 2
# Number of iterations (timeit): 1000
# Number of repeats (timeit): 10
# List lengths: [10, 20, 30, 40, 50, 60, 70, 80, 90]
#
# Algorithms:
# bubblesort
# bubblesort_2
# bubblesort_plus

# %% [markdown]
# ## sortperf.py on saiph

# %%
# %run sortperf.py
# Out:
# Number of iterations: 2
# Number of iterations (timeit): 1000
# Number of repeats (timeit): 10
# List lengths: [10, 20, 30, 40, 50, 60, 70, 80, 90]
#
# Algorithms:
# bubblesort
# bubblesort_2
# bubblesort_plus

# %%
# %run sortperf.py
# Out:
# Number of iterations: 2
# Number of iterations (timeit): 1000
# Number of repeats (timeit): 10
# List lengths: [10, 20, 30, 40, 50, 60, 70, 80, 90]
#
# Algorithms:
# bubblesort
# bubblesort_2
# bubblesort_plus

# %%
# %load_ext autoreload

# %%
# %autoreload 1

# %%
# %autoreload

# %%
# %run sortperf.py
# Out:
# Number of iterations: 2
# Number of iterations (timeit): 100
# Number of repeats (timeit): 5
# List lengths: [100, 200, 300]
#
# Algorithms:
# bubblesort
# bubblesort_2
# bubblesort_plus

# %%
# %run sortperf.py
# Out:
# Number of iterations: 2
# Number of iterations (timeit): 100
# Number of repeats (timeit): 10
# List lengths: [100, 150, 200, 250, 300]
#
# Algorithms:
# bubblesort
# bubblesort_2
# bubblesort_plus

# %%
# %run sortperf.py
# Out:
# Number of iterations: 2
# Number of iterations (timeit): 100
# Number of repeats (timeit): 10
# List lengths: [100, 150, 200, 250, 300]
#
# Algorithms:
# bubblesort
# bubblesort_2
# bubblesort_plus
